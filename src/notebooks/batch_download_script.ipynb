# %% [markdown]
# # Download Batch

# %% [markdown]
# ## Icechute

# %%
from project_manager import ProjectManager
project = ProjectManager('ice')
# Out:
# project already exists

# %%
project.save_catalog()
# Out:
# Querying products: 100%|██████████| 410/410 [00:08<00:00, 34.72 products/s]

# %%
df = project.get_dataframe()[project.get_dataframe().cloudcoverpercentage < 1]

# %%
df
# Out:
#                                                                                 summary  \
# ac4cc941-8e12-42a4-8b35-6ef1fdfb5d15  Date: 2020-09-04T14:00:21.024Z, Instrument: MS...
# 1685458f-3866-4cb5-a76d-22b3161e0031  Date: 2020-09-04T14:00:21.024Z, Instrument: MS...
# f403ef01-2edc-444d-94b5-bb680aadc9df  Date: 2020-08-29T13:40:51.024Z, Instrument: MS...
# b79721b0-8a39-463f-89fc-b09abec1461d  Date: 2020-08-29T13:40:51.024Z, Instrument: MS...
# 5b3059d1-a187-4578-812b-1e626e915a5f  Date: 2020-08-25T14:00:21.024Z, Instrument: MS...
# a20b6ea4-a6a9-409e-8786-feb20d9c05ec  Date: 2020-08-25T14:00:21.024Z, Instrument: MS...
# b68df3c1-92f7-4ee4-9052-09d2d43ceb1e  Date: 2020-08-24T13:37:29.024Z, Instrument: MS...
# b66845ab-a3a2-4948-a756-1873db0b2399  Date: 2020-08-24T13:37:29.024Z, Instrument: MS...
# 1a2a27ba-83e5-45ba-be14-4e2750bd1ab2  Date: 2020-07-01T13:57:39.024Z, Instrument: MS...
# 7c2e2640-4590-44b3-b2c1-a0eaa0b23063  Date: 2020-07-01T13:57:39.024Z, Instrument: MS...
# ...

# %%
index = df.index.values

# %%
project.download_data(index[0])
# Out:
# Downloading: 100%|██████████| 1.19G/1.19G [05:51<00:00, 3.39MB/s]
# MD5 checksumming: 100%|██████████| 1.19G/1.19G [00:01<00:00, 683MB/s]

# %%
project.batch_create_imagery()
# Out:
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ndvi = np.where((nir+red) == 0, 0, (nir-red)/(nir+red))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:131: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((green+vnir) == 0, 0, (green-vnir)/(green+vnir))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:99: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((swir+nir) == 0, 0, (swir-nir)/(swir+nir))

# %%
for i in range(2,16,2):
    project.download_data(index[i])
# Out:
# Downloading: 100%|██████████| 1.19G/1.19G [05:41<00:00, 3.49MB/s]
# MD5 checksumming: 100%|██████████| 1.19G/1.19G [00:01<00:00, 674MB/s]
# Downloading: 100%|██████████| 1.18G/1.18G [05:51<00:00, 3.37MB/s]
# MD5 checksumming: 100%|██████████| 1.18G/1.18G [00:01<00:00, 651MB/s]
# Downloading: 100%|██████████| 1.19G/1.19G [05:49<00:00, 3.40MB/s]
# MD5 checksumming: 100%|██████████| 1.19G/1.19G [00:01<00:00, 671MB/s]
# Downloading: 100%|██████████| 1.20G/1.20G [05:22<00:00, 3.74MB/s]
# MD5 checksumming: 100%|██████████| 1.20G/1.20G [00:01<00:00, 666MB/s]
# Downloading: 100%|██████████| 1.03G/1.03G [04:46<00:00, 3.60MB/s]
# MD5 checksumming: 100%|██████████| 1.03G/1.03G [00:01<00:00, 665MB/s]
# Downloading: 100%|██████████| 1.04G/1.04G [04:38<00:00, 3.73MB/s]
# MD5 checksumming: 100%|██████████| 1.04G/1.04G [00:01<00:00, 672MB/s]
# Downloading: 100%|██████████| 1.03G/1.03G [04:26<00:00, 3.87MB/s]
# MD5 checksumming: 100%|██████████| 1.03G/1.03G [00:01<00:00, 666MB/s]

# %%
project.batch_create_imagery()
# Out:
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ndvi = np.where((nir+red) == 0, 0, (nir-red)/(nir+red))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:131: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((green+vnir) == 0, 0, (green-vnir)/(green+vnir))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:99: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((swir+nir) == 0, 0, (swir-nir)/(swir+nir))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ndvi = np.where((nir+red) == 0, 0, (nir-red)/(nir+red))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:131: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((green+vnir) == 0, 0, (green-vnir)/(green+vnir))
# ...

# %% [markdown]
# # Icechute Alt

# %%
project = ProjectManager('icechuteAlt')

# %%
foot_print = project.get_footprint()

# %%
contained = []
for i in range(catalog.shape[0]):
    contained.append(foot_print.within(catalog['geometry'][i]))

# %%
contained

# %%
contained_cat = catalog[contained]

# %%
perfect = contained_cat[contained_cat.cloudcoverpercentage < 10]

# %%
perfect.shape

# %%
perfect.head(20)

# %%
to_download = perfect.index.values.tolist()

# %%
perfect.iloc[80:].head(20)

# %%
perfect.iloc[85:88]

# %%
perfect.iloc[85]

# %%
project.download_data(to_download[85])

# %%
project.download_data(to_download[86])

# %%
perfect.iloc[175:185]

# %%
perfect.iloc[180]

# %%
project.download_data(to_download[180])

# %% [markdown]
# # Fire Examples

# %%
from project_manager import ProjectManager
project = ProjectManager('fire2')
# Fire started 2020-08-16

# %%
footprint = project.get_footprint()

# %%
print(footprint)

# %%
catalog = project.get_catalog()

# %%
catalog

# %%
catalog.to_csv()

# %%
contained = []
for i in range(catalog.shape[0]):
    contained.append(footprint.within(catalog['geometry'][i]))

# %%
[footprint.within(geometry) for geometry in catalog['geometry']]

# %%
file = open('test.csv','w')
file.write(catalog[contained].to_csv())
file.close()

# %%
contained = []
for i in range(catalog.shape[0]):
    contained.append(footprint.within(catalog['geometry'][i]))

# %%
print(catalog['geometry'][i])

# %%
catalog.columns

# %%
filter = [
    'link','summary','summary',
    'beginposition','vegetationpercentage','notvegetatedpercentage',
    'waterpercentage','unclassifiedpercentage','mediumprobacloudspercentage',
    'highprobacloudspercentage','snowicepercentage','cloudcoverpercentage',
    'level1cpdiidentifier', 'geometry'
]

# %%
catalog[t]

# %%
filter

# %%
catalog[['link',]]

# %%
contained_cat = catalog[contained]

# %%
contained_cat.shape

# %%
perfect_sample = contained_cat[contained_cat.cloudcoverpercentage < 2]

# %%
perfect_sample

# %%
perfect_sample.index

# %%
'a3369779-3bdb-4b81-a222-07701f098ecc'

# %%
'aa628f87-5c02-4de9-969b-1f01f685a0a7'

# %%
to_download = perfect_sample.index.values.tolist()

# %%
perfect_sample.iloc[0].

# %% [markdown]
# # Run the command bellow to download the data

# %%
project.download_data(to_download[1])
project.download_data(to_download[10])

# %%
perfect_sample.iloc[7]

# %%
from projectManager import ProjectManager
project = ProjectManager('larger_fire')

# %%
footprint = project.get_footprint()

# %%
contained2 = []
for i in range(catalog.shape[0]):
    contained2.append(footprint.within(catalog['geometry'][i]))

# %%
contained == contained2

# %%
contained

# %%
contained2

# %% [markdown]
# # Phoenidownload_datarest Fire June 8-30 2020

# %%
from project_manager import ProjectManager
project = ProjectManager('phoenix')

# %%
footprint = project.get_footprint()

# %%
catalog = project.get_catalog()

# %%
contained = []
for i in range(catalog.shape[0]):
    contained.append(footprint.within(catalog['geometry'][i]))

# %%
contained

# %%
contained_cat = catalog[contained]

# %%
contained_cat.shape

# %%
perfect = contained_cat[contained_cat.cloudcoverpercentage < 10]
perfect.shape

# %%
perfect.iloc[7]

# %%
perfect.iloc[20]

# %%
to_download = perfect.index.values.tolist()

# %%
for i in range(20, 30, 2):
    project.download_data(to_download[i])

# %%
from project_manager import ProjectManager

# %%
project = ProjectManager('montreal')

# %%
path = project.find_image('2019_09_18','rgb')

# %%
path

# %%
gmm_path = '/mnt/alex/ssd/Machine learning/satelliteImagery/projects/montreal/classification/2019_09_18/cropped/4_normalized_gmm_rgb.tiff'

# %%
km_path = '/mnt/alex/ssd/Machine learning/satelliteImagery/projects/montreal/classification/2019_09_18/cropped/4_normalized_kmeans_rgb.tiff'

# %%
from raster_data import RasterData

# %%
gmm = RasterData(gmm_path)

# %%
np.unique(gmm.array, return_counts=True)

# %%
km = RasterData(km_path)

# %%
val_k = np.unique(km.array, return_counts=True)

# %%
val_k

# %%
np.mean(km.array != gmm.array)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(gmm.array*100)

# %%
plt.imshow(km.array)

# %%
gmm_arr = gmm.array*10+1

# %%
values = np.unique(gmm_arr, return_counts=True)

# %%
values

# %%
dict(zip(values))

# %%
list(zip(values))

# %%
equi = list(zip(values[0],values[1]))

# %%
equi.sort(key=lambda tup: tup[1])

# %%
equi

# %%
equivalences = [x[0] for x in equi]

# %%
zip(equivalences)

# %%
val_k

# %%
k_qui = list(zip(val_k[0],val_k[1]))

# %%
k_qui.sort(key=lambda tup: tup[1])

# %%
f = [k[0] for k in k_qui]

# %%
f

# %%
equivalences

# %%
gmm_arr

# %%
gmm_arr[gmm_arr == 11] = 0

# %%
t

# %%
plt.imshow(gmm_arr, cmap='terrain')
plt.colorbar()

# %%
plt.imshow(km.array,cmap='terrain')
plt.colorbar()

# %%
np.unique(gmm_arr, return_counts=True)

# %%
np.unique(km.array, return_counts=True)

# %%
plt.imshow(gmm.array,cmap='terrain')

# %%
# Ichechute

# %%
from project_manager import ProjectManager

# %%
project = ProjectManager('icechute')

# %%
footprint = project.get_footprint()

# %%
project.save_catalog()

# %%
catalog = project.get_catalog()

# %%
# Water sample

# %%
from project_manager import ProjectManager
project = ProjectManager('ice')
# Out:
# project already exists

# %%
catalog = project.get_catalog()
# Out:
# Querying products: 100%|██████████| 1038/1038 [00:26<00:00, 35.78 products/s]

# %%
project.save_catalog()
# Out:
# Querying products: 100%|██████████| 1038/1038 [00:41<00:00, 22.69 products/s]

# %%
catalog
# Out:
#                                                                                   title  \
# 342f860d-2e7a-429e-9e29-5a1d13ebf6ab  S2B_MSIL2A_20201003T152009_N0214_R068_T26XMN_2...
# 98e18b19-4678-4f1d-8b51-8c66b641c58e  S2B_MSIL2A_20201003T152009_N0214_R068_T25XEH_2...
# 001868bb-0ffd-47d2-801a-9308ec13877b  S2B_MSIL2A_20201002T155009_N0214_R054_T25XEH_2...
# cb6b3d97-11f4-42ce-b5b2-57d311a01708  S2B_MSIL2A_20201002T155009_N0214_R054_T26XMN_2...
# 2cd855f1-b210-4b1f-9ebb-8ca8a46af7d6  S2B_MSIL2A_20200929T153949_N0214_R011_T25XEH_2...
# ...                                                                                 ...
# 1ea2ae4d-4671-4216-84c3-6fd332029c47  S2B_MSIL2A_20200310T152949_N0214_R111_T25XEH_2...
# 579bf46b-1aab-4816-b873-ce8aef313749  S2B_MSIL2A_20200309T155959_N0214_R097_T25XEH_2...
# ea07d7f7-76e1-4354-9208-627f413d3425  S2B_MSIL2A_20200309T155959_N0214_R097_T26XMN_2...
# 42a9335c-9162-4ac9-a21b-9cba71fc4627  S2B_MSIL2A_20200307T151959_N0214_R068_T26XMN_2...
# ...

# %%
catalog[catalog.cloudcoverpercentage < 0.1]
# Out:
#                                                                                   title  \
# 2cd855f1-b210-4b1f-9ebb-8ca8a46af7d6  S2B_MSIL2A_20200929T153949_N0214_R011_T25XEH_2...
# 9f5d9135-c048-4adf-befa-c3c50d2b2916  S2B_MSIL2A_20200929T153949_N0214_R011_T26XMN_2...
# b71acee4-a04b-4379-bbe7-54b2ce981f27  S2B_MSIL2A_20200925T155929_N0214_R097_T25XEH_2...
# 950f5019-fd6f-4fe9-a3ce-15274127941c  S2B_MSIL2A_20200925T155929_N0214_R097_T26XMN_2...
# 9959eef9-1f59-4ec8-afc7-061459152c89  S2B_MSIL2A_20200926T152919_N0214_R111_T26XMN_2...
# ...                                                                                 ...
# 111cea3d-3e76-4204-b7c3-baa818a44cc9  S2B_MSIL2A_20200321T163859_N0214_R126_T26XMN_2...
# e2b4a7a3-9076-4889-97ee-3831e1137e00  S2B_MSIL2A_20200321T163859_N0214_R126_T25XEH_2...
# c2fa861a-5dc5-4ca3-b9a4-f783bc3f5e09  S2A_MSIL2A_20200321T154931_N0214_R054_T26XMN_2...
# 8c0d7d71-417f-4908-b537-7dd4fc37c491  S2A_MSIL2A_20200321T154931_N0214_R054_T25XEH_2...
# ...

# %%
to_download = df[df.cloudcoverpercentage < 0.1]

# %%
index = to_download.index.values

# %%
project.download_data(index[3])
project.download_data(index[10])

# %%
project.batch_create_imagery()

# %%
df = project.get_dataframe()

# %%
df.index.values[4]
# Out:
# '2cd855f1-b210-4b1f-9ebb-8ca8a46af7d6'

# %%
project.download_data('2cd855f1-b210-4b1f-9ebb-8ca8a46af7d6')
# Out:
# Downloading: 100%|██████████| 973M/973M [07:14<00:00, 2.24MB/s]
# MD5 checksumming: 100%|██████████| 973M/973M [00:01<00:00, 664MB/s]

# %%
project.batch_create_imagery()
# Out:
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:126: RuntimeWarning: invalid value encountered in true_divide
#   ndvi = np.where((nir+red) == 0, 0, (nir-red)/(nir+red))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:97: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((swir+nir) == 0, 0, (swir-nir)/(swir+nir))

# %%
catalog
# Out:
#                                                                                   title  \
# 342f860d-2e7a-429e-9e29-5a1d13ebf6ab  S2B_MSIL2A_20201003T152009_N0214_R068_T26XMN_2...
# 98e18b19-4678-4f1d-8b51-8c66b641c58e  S2B_MSIL2A_20201003T152009_N0214_R068_T25XEH_2...
# 001868bb-0ffd-47d2-801a-9308ec13877b  S2B_MSIL2A_20201002T155009_N0214_R054_T25XEH_2...
# cb6b3d97-11f4-42ce-b5b2-57d311a01708  S2B_MSIL2A_20201002T155009_N0214_R054_T26XMN_2...
# 2cd855f1-b210-4b1f-9ebb-8ca8a46af7d6  S2B_MSIL2A_20200929T153949_N0214_R011_T25XEH_2...
# ...                                                                                 ...
# 1ea2ae4d-4671-4216-84c3-6fd332029c47  S2B_MSIL2A_20200310T152949_N0214_R111_T25XEH_2...
# 579bf46b-1aab-4816-b873-ce8aef313749  S2B_MSIL2A_20200309T155959_N0214_R097_T25XEH_2...
# ea07d7f7-76e1-4354-9208-627f413d3425  S2B_MSIL2A_20200309T155959_N0214_R097_T26XMN_2...
# 42a9335c-9162-4ac9-a21b-9cba71fc4627  S2B_MSIL2A_20200307T151959_N0214_R068_T26XMN_2...
# ...

# %%
cand = catalog[catalog.cloudcoverpercentage < 0.1]

# %%
cand
# Out:
#                                                                                   title  \
# 2cd855f1-b210-4b1f-9ebb-8ca8a46af7d6  S2B_MSIL2A_20200929T153949_N0214_R011_T25XEH_2...
# 9f5d9135-c048-4adf-befa-c3c50d2b2916  S2B_MSIL2A_20200929T153949_N0214_R011_T26XMN_2...
# b71acee4-a04b-4379-bbe7-54b2ce981f27  S2B_MSIL2A_20200925T155929_N0214_R097_T25XEH_2...
# 950f5019-fd6f-4fe9-a3ce-15274127941c  S2B_MSIL2A_20200925T155929_N0214_R097_T26XMN_2...
# 9959eef9-1f59-4ec8-afc7-061459152c89  S2B_MSIL2A_20200926T152919_N0214_R111_T26XMN_2...
# ...                                                                                 ...
# 111cea3d-3e76-4204-b7c3-baa818a44cc9  S2B_MSIL2A_20200321T163859_N0214_R126_T26XMN_2...
# e2b4a7a3-9076-4889-97ee-3831e1137e00  S2B_MSIL2A_20200321T163859_N0214_R126_T25XEH_2...
# c2fa861a-5dc5-4ca3-b9a4-f783bc3f5e09  S2A_MSIL2A_20200321T154931_N0214_R054_T26XMN_2...
# 8c0d7d71-417f-4908-b537-7dd4fc37c491  S2A_MSIL2A_20200321T154931_N0214_R054_T25XEH_2...
# ...

# %%
df
# Out:
#                                                                                 summary  \
# 342f860d-2e7a-429e-9e29-5a1d13ebf6ab  Date: 2020-10-03T15:20:09.024Z, Instrument: MS...
# 98e18b19-4678-4f1d-8b51-8c66b641c58e  Date: 2020-10-03T15:20:09.024Z, Instrument: MS...
# 001868bb-0ffd-47d2-801a-9308ec13877b  Date: 2020-10-02T15:50:09.024Z, Instrument: MS...
# cb6b3d97-11f4-42ce-b5b2-57d311a01708  Date: 2020-10-02T15:50:09.024Z, Instrument: MS...
# 2cd855f1-b210-4b1f-9ebb-8ca8a46af7d6  Date: 2020-09-29T15:39:49.024Z, Instrument: MS...
# ...                                                                                 ...
# 1ea2ae4d-4671-4216-84c3-6fd332029c47  Date: 2020-03-10T15:29:49.024Z, Instrument: MS...
# 579bf46b-1aab-4816-b873-ce8aef313749  Date: 2020-03-09T15:59:59.024Z, Instrument: MS...
# ea07d7f7-76e1-4354-9208-627f413d3425  Date: 2020-03-09T15:59:59.024Z, Instrument: MS...
# 42a9335c-9162-4ac9-a21b-9cba71fc4627  Date: 2020-03-07T15:19:59.024Z, Instrument: MS...
# ...

# %%
d = df[df.cloudcoverpercentage < 1]

# %%
d
# Out:
#                                                                                 summary  \
# 2cd855f1-b210-4b1f-9ebb-8ca8a46af7d6  Date: 2020-09-29T15:39:49.024Z, Instrument: MS...
# 9f5d9135-c048-4adf-befa-c3c50d2b2916  Date: 2020-09-29T15:39:49.024Z, Instrument: MS...
# b71acee4-a04b-4379-bbe7-54b2ce981f27  Date: 2020-09-25T15:59:29.024Z, Instrument: MS...
# 950f5019-fd6f-4fe9-a3ce-15274127941c  Date: 2020-09-25T15:59:29.024Z, Instrument: MS...
# 704b93e8-7205-42c6-ab63-d3b472e94759  Date: 2020-09-27T16:39:49.024Z, Instrument: MS...
# ...                                                                                 ...
# 111cea3d-3e76-4204-b7c3-baa818a44cc9  Date: 2020-03-21T16:38:59.024Z, Instrument: MS...
# e2b4a7a3-9076-4889-97ee-3831e1137e00  Date: 2020-03-21T16:38:59.024Z, Instrument: MS...
# c2fa861a-5dc5-4ca3-b9a4-f783bc3f5e09  Date: 2020-03-21T15:49:31.024Z, Instrument: MS...
# 8c0d7d71-417f-4908-b537-7dd4fc37c491  Date: 2020-03-21T15:49:31.024Z, Instrument: MS...
# ...

# %%
download = d.index.values

# %%
download[10]
# Out:
# 'c0dfdac0-bc23-4277-8785-a7fd8209449c'

# %%
project.download_data('c0dfdac0-bc23-4277-8785-a7fd8209449c')
# Out:
# Downloading: 100%|██████████| 976M/976M [09:55<00:00, 1.64MB/s]
# MD5 checksumming: 100%|██████████| 976M/976M [00:01<00:00, 674MB/s]

# %%
path = '/mnt/alex/ssd/Machine learning/projects/ice/data/2020_09_27/Granule/'
p = '/mnt/alex/ssd/Machine learning/satelliteImagery/projects/ice/data/2020_09_29/GRANULE/L2A_T25XEH_A018627_20200929T153944/IMG_DATA/R60m/'
b4 = 'T25XEH_20200929T153949_B04_60m'
b3 =
# Out:
#   File "<ipython-input-1-9cf22acbf972>", line 4
#     b3 =
#          ^
# SyntaxError: invalid syntax

# %%
from project_manager import ProjectManager

# %%
project = ProjectManager('iceland_mountain')
# Out:
# project created succesfully

# %%
project.get_footprint()

# %%
project.get_catalog()
# Out:
# Querying products:  51%|█████▏    | 100/195 [00:00<?, ? products/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-81e8bcecf120> in <module>
# ----> 1 project.get_catalog()
#
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/project_manager.py in get_catalog(self)
#     176         """
#     177         footprint = self.get_footprint()
# --> 178         query = self.api_session.query(footprint)
#     179         return self.api_session.to_geo_df(query)
#     180
#
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/api_session.py in query(self, footprint)
#      54         return self.api.query(footprint, date=(query['begin'], query['end']),
#      55                               platformname=query['platform'],
# ---> 56                               processinglevel=query['processing'])
#      57
#      58     def to_geo_df(self, product):
#
# ...

# %%
project.save_catalog()
# Out:
# ...
# Querying products: 100%|██████████| 195/195 [00:03<00:00, 25.44 products/s]

# %%
df = project.get_dataframe()

# %%
df[df.cloudcoverpercentage < 5]
# Out:
#                                                                                 summary  \
# 98b36750-e7e7-46ac-89d4-67370f4c1994  Date: 2020-10-13T12:53:11.024Z, Instrument: MS...
# f8fbfa15-dfe3-4841-9cc4-66f1dc2a8431  Date: 2020-10-01T13:02:59.024Z, Instrument: MS...
# 89e0b392-2dbc-4344-b4f2-fd11a3d5ce46  Date: 2020-08-22T13:03:09.024Z, Instrument: MS...
# 7c1f2977-0869-4e56-9815-8a87bd10ad2f  Date: 2020-08-14T12:53:11.024Z, Instrument: MS...
# 35a4c3f7-3381-4687-9d8c-8686d5ca11fc  Date: 2020-06-30T12:53:09.024Z, Instrument: MS...
# d0f56fa5-008d-4ffd-997e-86dcd7a04ec7  Date: 2020-06-18T13:03:11.024Z, Instrument: MS...
# 7088b6ad-8443-41e1-ba5d-772392dd94fb  Date: 2020-04-29T13:03:01.024Z, Instrument: MS...
# eb0f4410-2d15-4e2e-80bf-a4d22b568f91  Date: 2020-04-26T12:53:01.024Z, Instrument: MS...
# a0600216-f44b-4f30-a539-c086c77d9c23  Date: 2020-04-21T12:52:59.024Z, Instrument: MS...
# 6250f3d9-41b2-4b7e-ab4f-9aafbb45d964  Date: 2020-04-09T13:03:01.024Z, Instrument: MS...
# ...

# %%
df[df.cloudcoverpercentage < 5].index.values
# Out:
# array(['98b36750-e7e7-46ac-89d4-67370f4c1994',
#        'f8fbfa15-dfe3-4841-9cc4-66f1dc2a8431',
#        '89e0b392-2dbc-4344-b4f2-fd11a3d5ce46',
#        '7c1f2977-0869-4e56-9815-8a87bd10ad2f',
#        '35a4c3f7-3381-4687-9d8c-8686d5ca11fc',
#        'd0f56fa5-008d-4ffd-997e-86dcd7a04ec7',
#        '7088b6ad-8443-41e1-ba5d-772392dd94fb',
#        'eb0f4410-2d15-4e2e-80bf-a4d22b568f91',
#        'a0600216-f44b-4f30-a539-c086c77d9c23',
#        '6250f3d9-41b2-4b7e-ab4f-9aafbb45d964',
#        '21484898-2063-496b-bdba-85fb536a37d4',
#        'e4a56ac4-f08f-4a1e-ae92-940eb37efee9'], dtype=object)

# %%
from project_manager import ProjectManager
project = ProjectManager('mountain3')
# Out:
# project created succesfully

# %%
project.get_footprint()

# %%
project.save_catalog()
# Out:
# Querying products: 100%|██████████| 382/382 [00:14<00:00, 19.55 products/s]

# %%
df = project.get_dataframe()

# %%
df = df[df.cloudcoverpercentage < 1]

# %%
df.index.values[0]
# Out:
# '5887346c-e179-48bf-b971-d412fe58eed8'

# %%
df.sort_values('waterpercentage',ascending=False)
# Out:
# Empty DataFrame
# Columns: [summary, vegetationpercentage, notvegetatedpercentage, waterpercentage, unclassifiedpercentage, snowicepercentage, cloudcoverpercentage, geometry, size]
# Index: []

# %%
index = df.sort_values('waterpercentage',ascending=False).index.values

# %%
project.download_data(index[0])
# Out:
# Downloading: 100%|██████████| 177M/177M [02:13<00:00, 1.32MB/s]
# MD5 checksumming: 100%|██████████| 177M/177M [00:00<00:00, 657MB/s]

# %%
project.batch_create_imagery()
# Out:
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:126: RuntimeWarning: invalid value encountered in true_divide
#   ndvi = np.where((nir+red) == 0, 0, (nir-red)/(nir+red))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:97: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((swir+nir) == 0, 0, (swir-nir)/(swir+nir))

# %%
df.sort_values('snowicepercentage',ascending=True).index.values[0]
# Out:
# 'bb1db987-f85e-4b9c-b76b-da102df37f06'

# %%
project.download_data('5887346c-e179-48bf-b971-d412fe58eed8')
# Out:
# Downloading: 100%|██████████| 991M/991M [07:33<00:00, 2.19MB/s]
# MD5 checksumming: 100%|██████████| 991M/991M [00:01<00:00, 652MB/s]

# %%
project.batch_create_imagery()
# Out:
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:126: RuntimeWarning: invalid value encountered in true_divide
#   ndvi = np.where((nir+red) == 0, 0, (nir-red)/(nir+red))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:97: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((swir+nir) == 0, 0, (swir-nir)/(swir+nir))

# %%
from project_manager import ProjectManager

# %%
project = ProjectManager('ground11')
# Out:
# project created succesfully

# %%
project.save_catalog()
# Out:
# Querying products: 100%|██████████| 155/155 [00:06<00:00,  8.45 products/s]

# %%
df = project.get_dataframe()

# %%
noclouds = df[df.cloudcoverpercentage < 1]

# %%
noclouds
# Out:
#                                                                                 summary  \
# 177f6676-c839-4179-b863-f873fe993f87  Date: 2020-09-28T14:29:09.024Z, Instrument: MS...
#
#                                       vegetationpercentage  \
# 177f6676-c839-4179-b863-f873fe993f87              1.330088
#
#                                       notvegetatedpercentage  waterpercentage  \
# 177f6676-c839-4179-b863-f873fe993f87                1.876901        92.586493
#
#                                       unclassifiedpercentage  \
# 177f6676-c839-4179-b863-f873fe993f87                0.472218
#
#                                       snowicepercentage  cloudcoverpercentage  \
# 177f6676-c839-4179-b863-f873fe993f87           1.118563              0.714603
#
#                                                                                geometry  \
# 177f6676-c839-4179-b863-f873fe993f87  MULTIPOLYGON (((-46.763885 59.43861634029021, ...
#
# ...

# %%
from project_manager import ProjectManager

# %%
project = ProjectManager('water8')
# Out:
# project created succesfully

# %%
project.save_catalog()
# Out:
# Querying products: 100%|██████████| 309/309 [00:13<00:00, 16.05 products/s]

# %%
df = project.get_dataframe()

# %%
noclouds = df[df.cloudcoverpercentage < 1]

# %%
noclouds
# Out:
#                                                                                 summary  \
# 4c0c9776-f19f-4d4e-80b0-8cf43e73dba7  Date: 2020-07-31T19:49:11.024Z, Instrument: MS...
# 7ef11878-8f53-4a91-9309-122c6ff9be2c  Date: 2020-06-13T19:39:09.024Z, Instrument: MS...
# c6cb424d-0db6-44ab-8ade-62b12686026e  Date: 2020-05-24T19:39:09.024Z, Instrument: MS...
# f52dd6a2-3586-46a3-8e33-559a6556d95a  Date: 2020-05-22T19:49:11.024Z, Instrument: MS...
# 4547ff83-fe4a-48c9-b9bd-8ae5f4a8e541  Date: 2020-05-12T19:49:11.024Z, Instrument: MS...
# b837e73b-b7d8-4d19-a4ac-a6dfcadef81b  Date: 2020-05-09T19:39:11.024Z, Instrument: MS...
# 229e87ac-d7c3-4d89-bacd-7cb142c9051c  Date: 2020-05-04T19:38:59.024Z, Instrument: MS...
# 68180efc-3fea-4b21-a222-8ce052493fd3  Date: 2020-04-29T19:39:11.024Z, Instrument: MS...
# 8651730d-8794-4fc9-9cad-923ac1e552d1  Date: 2020-04-24T19:38:59.024Z, Instrument: MS...
# 4a42fbc5-1719-4ed6-a2e5-70ce91797d15  Date: 2020-04-17T19:48:59.024Z, Instrument: MS...
# ...

# %%
project.download_data(noclouds.index.values[0])
# Out:
# Downloading: 100%|██████████| 830M/830M [04:14<00:00, 3.26MB/s]
# MD5 checksumming: 100%|██████████| 830M/830M [00:01<00:00, 673MB/s]

# %%
# Out:
#   File "<ipython-input-59-22d00e838d74>", line 1
#     from project
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Forest Download

# %%
from project_manager import ProjectManager

# %%
project = ProjectManager('ice')
# Out:
# project already exists

# %%
project.save_catalog()
# Out:
# Querying products: 100%|██████████| 329/329 [00:06<00:00, 33.31 products/s]

# %%
df = project.get_dataframe()

# %%
df = df[df.cloudcoverpercentage < 1]

# %%
df.tail(10)
# Out:
#                                                                                 summary  vegetationpercentage  ...                                           geometry       size
# a20b6ea4-a6a9-409e-8786-feb20d9c05ec  Date: 2020-08-25T14:00:21.024Z, Instrument: MS...              0.244375  ...  MULTIPOLYGON (((-20.93509 71.91662516221517, -...    1.10 GB
# b68df3c1-92f7-4ee4-9052-09d2d43ceb1e  Date: 2020-08-24T13:37:29.024Z, Instrument: MS...              0.253469  ...  MULTIPOLYGON (((-23.899933 71.9897729527755, -...    1.11 GB
# b66845ab-a3a2-4948-a756-1873db0b2399  Date: 2020-08-24T13:37:29.024Z, Instrument: MS...              0.256582  ...  MULTIPOLYGON (((-20.93509 71.91662516221517, -...    1.10 GB
# 1a2a27ba-83e5-45ba-be14-4e2750bd1ab2  Date: 2020-07-01T13:57:39.024Z, Instrument: MS...              1.405057  ...  MULTIPOLYGON (((-23.899933 71.9897729527755, -...    1.12 GB
# ...

# %%
index = df.index.values
for i in range(10):
    project.download_data(index[i])
# Out:
# Downloading: 100%|██████████| 1.12G/1.12G [05:19<00:00, 3.49MB/s]
# MD5 checksumming: 100%|██████████| 1.12G/1.12G [00:01<00:00, 663MB/s]
# Downloading: 100%|██████████| 1.13G/1.13G [05:31<00:00, 3.41MB/s]
# MD5 checksumming: 100%|██████████| 1.13G/1.13G [00:01<00:00, 663MB/s]
# Downloading: 100%|██████████| 1.13G/1.13G [05:25<00:00, 3.48MB/s]
# MD5 checksumming: 100%|██████████| 1.13G/1.13G [00:01<00:00, 660MB/s]
# Downloading: 100%|██████████| 1.11G/1.11G [05:17<00:00, 3.48MB/s]
# MD5 checksumming: 100%|██████████| 1.11G/1.11G [00:01<00:00, 662MB/s]
# Downloading: 100%|██████████| 1.14G/1.14G [04:55<00:00, 3.85MB/s]
# MD5 checksumming: 100%|██████████| 1.14G/1.14G [00:01<00:00, 660MB/s]
# Downloading: 100%|██████████| 1.11G/1.11G [05:13<00:00, 3.54MB/s]
# MD5 checksumming: 100%|██████████| 1.11G/1.11G [00:01<00:00, 667MB/s]
# Downloading: 100%|██████████| 1.14G/1.14G [05:11<00:00, 3.67MB/s]
# MD5 checksumming: 100%|██████████| 1.14G/1.14G [00:01<00:00, 659MB/s]
# ...

# %%
for i in range(10,15):
    project.download_data(index[i])
# Out:
# Downloading: 100%|██████████| 92.9M/92.9M [00:47<00:00, 1.94MB/s]
# MD5 checksumming: 100%|██████████| 92.9M/92.9M [00:00<00:00, 646MB/s]
# Downloading: 100%|██████████| 1.10G/1.10G [05:04<00:00, 3.61MB/s]
# MD5 checksumming: 100%|██████████| 1.10G/1.10G [00:01<00:00, 661MB/s]
# Downloading: 100%|██████████| 1.15G/1.15G [04:44<00:00, 4.05MB/s]
# MD5 checksumming: 100%|██████████| 1.15G/1.15G [00:01<00:00, 680MB/s]
# Downloading: 100%|██████████| 1.15G/1.15G [04:51<00:00, 3.93MB/s]
# MD5 checksumming: 100%|██████████| 1.15G/1.15G [00:01<00:00, 679MB/s]
# Downloading: 100%|██████████| 1.11G/1.11G [04:42<00:00, 3.91MB/s]
# MD5 checksumming: 100%|██████████| 1.11G/1.11G [00:01<00:00, 664MB/s]

# %%
for i in range(15,25):
#     project.download_data(index[i])
# Out:
#   File "<ipython-input-29-659badf734ed>", line 2
#     #     project.download_data(index[i])
#                                          ^
# SyntaxError: unexpected EOF while parsing

# %%
project.batch_create_imagery()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-9725d374446c> in <module>
# ----> 1 project.batch_create_imagery()
#
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/project_manager.py in batch_create_imagery(self)
#     242         for data_file in all_dates:
#     243             tmp_info = self.__create_resolution_index(data_file)
# --> 244             image_creator.create_batch_images(tmp_info, self)
#     245
#     246     def __create_resolution_index(self, selected_file):
#
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py in create_batch_images(index, project)
#      19     """
#      20     output = index[1]
# ---> 21     create_rgb(index, project, output)
#      22     create_ndvi(index, project, output)
#      23     create_ndwi(index, project, output)
#
# ...

# %%
project = ProjectManager('aus')
# Out:
# project created succesfully

# %%
project.save_catalog()

# %%
df = project.get_dataframe()

# %%
df = df[df.cloudcoverpercentage < 1]

# %%
index = df.index.values

# %%
df
# Out:
#                                                                                 summary  vegetationpercentage  ...                                           geometry       size
# 7587080c-12f4-4991-8c01-c1ab37e12279  Date: 2020-04-19T00:02:41.024Z, Instrument: MS...             66.853017  ...  MULTIPOLYGON (((148.1127268618953 -36.22789729...    1.08 GB
# 5c9b7518-a291-475c-ba2e-de9894f48fea  Date: 2020-04-17T00:11:09.024Z, Instrument: MS...             73.367190  ...  MULTIPOLYGON (((148.1127268618953 -36.22789729...  705.38 MB
# 83b8b90b-1f76-49f2-8070-64e21588f149  Date: 2020-03-15T00:02:39.024Z, Instrument: MS...             63.668412  ...  MULTIPOLYGON (((148.1127268618953 -36.22789729...    1.08 GB
# 15760b1a-b65d-4e55-9f01-ea1e68b02bdb  Date: 2019-12-16T00:02:39.024Z, Instrument: MS...             56.874317  ...  MULTIPOLYGON (((148.1127268618953 -36.22789729...    1.09 GB
# ...

# %%
project.download_data(index[1])
project.download_data(index[2])
# Out:
# Downloading: 100%|██████████| 740M/740M [03:35<00:00, 3.43MB/s]
# MD5 checksumming: 100%|██████████| 740M/740M [00:01<00:00, 664MB/s]
# Downloading: 100%|██████████| 1.16G/1.16G [06:05<00:00, 3.17MB/s]
# MD5 checksumming: 100%|██████████| 1.16G/1.16G [00:01<00:00, 665MB/s]

# %%
project.batch_create_imagery()
# Out:
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ndvi = np.where((nir+red) == 0, 0, (nir-red)/(nir+red))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:131: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((green+vnir) == 0, 0, (green-vnir)/(green+vnir))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:99: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((swir+nir) == 0, 0, (swir-nir)/(swir+nir))

# %%
from project_manager import ProjectManager

# %%
project = ProjectManager('california_forest')
# Out:
# project created succesfully

# %%
project.save_catalog()

# %%
df = project.get_dataframe()

# %%
noclouds = df[df.cloudcoverpercentage < 1]

# %%
noclouds
# Out:
#                                                                                 summary  ...       size
# f44abad0-f8b4-4b61-982b-fbbfe0375822  Date: 2020-10-19T19:04:19.024Z, Instrument: MS...  ...    1.05 GB
# aa6a3f5b-4546-45a7-9d13-6b66e146f27b  Date: 2020-10-14T19:03:51.024Z, Instrument: MS...  ...    1.06 GB
# f23ce91d-547c-4f52-bef7-b34df0c9700e  Date: 2020-08-15T18:59:21.024Z, Instrument: MS...  ...    1.04 GB
# 09ad21fa-3384-467d-aed9-a07c20b9de5e  Date: 2020-07-11T18:59:19.024Z, Instrument: MS...  ...    1.08 GB
# ddffd263-1b04-48d4-8e4f-da08736c6dcd  Date: 2020-07-06T18:59:21.024Z, Instrument: MS...  ...    1.07 GB
# 3b36fa39-8494-4849-bc0f-f5e0065624b1  Date: 2020-07-01T18:59:19.024Z, Instrument: MS...  ...    1.08 GB
# cd58d88d-32e0-470d-b716-ad15506cfcac  Date: 2020-04-02T18:59:19.024Z, Instrument: MS...  ...    1.04 GB
# d6445c9d-8df2-4a2b-8148-f3a9699a8b72  Date: 2020-03-03T19:02:59.024Z, Instrument: MS...  ...    1.04 GB
# ...

# %%
index = noclouds.index.values

# %%
for i in range(5):
    project.download_data(index[i])
# Out:
# Downloading: 100%|██████████| 1.13G/1.13G [08:34<00:00, 2.19MB/s]
# MD5 checksumming: 100%|██████████| 1.13G/1.13G [00:01<00:00, 660MB/s]
# Downloading: 100%|██████████| 1.14G/1.14G [12:26<00:00, 1.53MB/s]
# MD5 checksumming: 100%|██████████| 1.14G/1.14G [00:01<00:00, 649MB/s]
# Downloading: 100%|██████████| 1.12G/1.12G [10:54<00:00, 1.70MB/s]
# MD5 checksumming: 100%|██████████| 1.12G/1.12G [00:01<00:00, 669MB/s]
# Downloading: 100%|██████████| 1.16G/1.16G [12:18<00:00, 1.57MB/s]
# MD5 checksumming: 100%|██████████| 1.16G/1.16G [00:01<00:00, 658MB/s]
# Downloading: 100%|██████████| 1.15G/1.15G [10:57<00:00, 1.74MB/s]
# MD5 checksumming: 100%|██████████| 1.15G/1.15G [00:01<00:00, 654MB/s]

# %%
from project_manager import ProjectManager

# %%
project= ProjectManager('fire')
# Out:
# project already exists

# %%
from project_manager import ProjectManager

# %%
project = ProjectManager('desert')
# Out:
# project created succesfully

# %%
project.save_catalog()

# %%
df = project.get_dataframe()

# %%
df
# Out:
#                                                                                 summary  ...       size
# 1d78538a-e27e-42ad-b0a7-50a0404a4b4b  Date: 2020-11-09T17:45:51.024Z, Instrument: MS...  ...    1.07 GB
# 40a5a271-7c4c-4a30-82fc-44614d10955d  Date: 2020-11-04T17:45:19.024Z, Instrument: MS...  ...    1.07 GB
# 9645ecf5-6fac-4382-94f3-c4722e1ff6ae  Date: 2020-10-30T17:44:51.024Z, Instrument: MS...  ...    1.07 GB
# 08b8fd61-e023-4ee4-9ed4-aa317b95a743  Date: 2020-10-25T17:44:29.024Z, Instrument: MS...  ...  728.95 MB
# f71d3e4f-fd59-4a5e-a606-f658a8f901a0  Date: 2020-10-20T17:43:51.024Z, Instrument: MS...  ...    1.07 GB
# ...                                                                                 ...  ...        ...
# 065ae6ff-d072-4374-8364-1ba6f7c9ad34  Date: 2019-10-21T17:43:49.024Z, Instrument: MS...  ...    1.09 GB
# 8e063555-7895-473c-bda7-33a577fc2877  Date: 2019-10-16T17:43:21.024Z, Instrument: MS...  ...    1.10 GB
# ...

# %%
noclouds = df[df.cloudcoverpercentage < 0.5]

# %%
noclouds
# Out:
#                                                                                 summary  ...     size
# 9645ecf5-6fac-4382-94f3-c4722e1ff6ae  Date: 2020-10-30T17:44:51.024Z, Instrument: MS...  ...  1.07 GB
# 289e7a4a-e5a7-4d3e-a529-e04aa34a13e6  Date: 2020-10-15T17:43:19.024Z, Instrument: MS...  ...  1.09 GB
# 4f6240f5-d900-41b6-9cab-26200ff75cde  Date: 2020-10-10T17:42:51.024Z, Instrument: MS...  ...  1.08 GB
# 43bfff5c-61ab-45b3-8493-0ee0ba78af9e  Date: 2020-09-30T17:41:41.024Z, Instrument: MS...  ...  1.08 GB
# 0b44b1cc-6e8a-4caa-b38c-a04294ec0331  Date: 2020-09-25T17:40:09.024Z, Instrument: MS...  ...  1.08 GB
# 22acae8d-1f90-446c-b62f-7def1274b2bb  Date: 2020-09-20T17:40:31.024Z, Instrument: MS...  ...  1.06 GB
# 18fb1342-6ed4-464c-82bf-36ca8c21f281  Date: 2020-09-05T17:39:09.024Z, Instrument: MS...  ...  1.08 GB
# c036c8aa-ba99-41f4-a067-c0078cba4068  Date: 2020-08-26T17:39:09.024Z, Instrument: MS...  ...  1.07 GB
# ...

# %%
index = df.index.values

# %%
project.download_data(index[1])
# Out:
# Downloading: 100%|██████████| 1.15G/1.15G [09:37<00:00, 1.98MB/s]
# MD5 checksumming: 100%|██████████| 1.15G/1.15G [00:01<00:00, 647MB/s]

# %%
project.batch_create_imagery()
# Out:
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ndvi = np.where((nir+red) == 0, 0, (nir-red)/(nir+red))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:131: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((green+vnir) == 0, 0, (green-vnir)/(green+vnir))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:99: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((swir+nir) == 0, 0, (swir-nir)/(swir+nir))

# %% [markdown]
# # Iqualuit Data Download

# %%
from project_manager import ProjectManager

# %%
project = ProjectManager('iqualuit')
# Out:
# project created succesfully

# %%
project.save_catalog()
# Out:
# Querying products: 100%|██████████| 202/202 [00:03<00:00, 25.62 products/s]

# %%
df = project.get_dataframe()

# %%
df = df[df.cloudcoverpercentage < 1]

# %%
df.shape
# Out:
# (8, 9)

# %%
index = df.index.values

# %%
index
# Out:
# array(['affabb3d-8fa6-4cd2-a5bc-854a09527b28',
#        'dea8be03-1934-4b99-b52d-0f0269b19bb6',
#        'ad566a5f-6df7-4cef-965d-828876818eb0',
#        '3a981b19-a652-4738-b061-89b0f5c1bf06',
#        '3cec207a-a4f9-47f7-b023-ff66e1b77335',
#        '8c6d63fb-1a00-470a-bece-66eb9dd51a87',
#        '1fc905ae-c22f-4c2d-8660-0f9f17678cc5',
#        '38f367dd-36ab-4e2a-b715-0f5a8b902eda'], dtype=object)

# %%
for i in index:
    project.download_data(i)
# Out:
# Downloading: 100%|██████████| 941M/941M [07:48<00:00, 2.01MB/s]
# MD5 checksumming: 100%|██████████| 941M/941M [00:01<00:00, 653MB/s]
# Downloading: 100%|██████████| 421M/421M [03:55<00:00, 1.79MB/s]
# MD5 checksumming: 100%|██████████| 421M/421M [00:00<00:00, 648MB/s]
# Downloading: 100%|██████████| 426M/426M [03:14<00:00, 2.19MB/s]
# MD5 checksumming: 100%|██████████| 426M/426M [00:00<00:00, 522MB/s]
# Downloading: 100%|██████████| 489M/489M [03:03<00:00, 2.67MB/s]
# MD5 checksumming: 100%|██████████| 489M/489M [00:00<00:00, 634MB/s]
# Downloading: 100%|██████████| 480M/480M [04:39<00:00, 1.72MB/s]
# MD5 checksumming: 100%|██████████| 480M/480M [00:00<00:00, 639MB/s]
# Downloading: 100%|██████████| 1.04G/1.04G [09:18<00:00, 1.87MB/s]
# MD5 checksumming: 100%|██████████| 1.04G/1.04G [00:01<00:00, 653MB/s]
# Downloading: 100%|██████████| 1.05G/1.05G [08:28<00:00, 2.06MB/s]
# MD5 checksumming: 100%|██████████| 1.05G/1.05G [00:01<00:00, 651MB/s]
# ...

# %%
# project.download_data('2aaa1ac7-fa5e-4cee-ac5a-d7ca41eaa7f4')
# project.download_data('0ddc0ea7-3050-4d6a-95b9-182a2809ad79')
project.download_data('2f6efe2f-8216-4399-ba2c-edb06015da0c')
# Out:
# Downloading: 100%|██████████| 451M/451M [03:52<00:00, 1.94MB/s]
# MD5 checksumming: 100%|██████████| 451M/451M [00:00<00:00, 648MB/s]

# %%
project.batch_create_imagery()
# Out:
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ndvi = np.where((nir+red) == 0, 0, (nir-red)/(nir+red))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:131: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((green+vnir) == 0, 0, (green-vnir)/(green+vnir))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:99: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((swir+nir) == 0, 0, (swir-nir)/(swir+nir))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ndvi = np.where((nir+red) == 0, 0, (nir-red)/(nir+red))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:131: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((green+vnir) == 0, 0, (green-vnir)/(green+vnir))
# ...

# %% [markdown]
# # Montreal Data Winter

# %%
from project_manager import ProjectManager
project = ProjectManager('montreal')
# Out:
# project already exists

# %%
project.save_catalog()
# Out:
# Querying products: 100%|██████████| 164/164 [00:07<00:00,  8.01 products/s]

# %%
df = project.get_dataframe()

# %%
df = df[df.cloudcoverpercentage < 5]

# %%
df
# Out:
#                                                                                 summary  \
# e7374d4a-c176-464c-b2dc-abc15c55e482  Date: 2020-10-17T15:52:51.024Z, Instrument: MS...
# 86f3855e-f825-4e6f-be82-7a814cd1815a  Date: 2020-10-12T15:51:19.024Z, Instrument: MS...
# b890b664-1628-46a4-9fb7-ee96d1e8d9f1  Date: 2020-10-12T15:51:19.024Z, Instrument: MS...
# 4f985684-e7b0-4ce1-9fc7-00d5818211ae  Date: 2020-09-22T15:48:59.024Z, Instrument: MS...
# 25b2da07-a440-46c8-829c-cfbe7f2b72be  Date: 2020-09-22T15:48:59.024Z, Instrument: MS...
# f846d1a1-40df-4d43-b144-6b42d1aa99d4  Date: 2020-08-08T15:49:11.024Z, Instrument: MS...
# 99d48837-c73e-4916-9d87-8c17ee9c3c0e  Date: 2020-08-08T15:49:11.024Z, Instrument: MS...
# 59d48a05-0a60-4224-9b93-27787708cffc  Date: 2020-07-24T15:48:19.024Z, Instrument: MS...
# 0fa56580-65cd-4d9e-a1b0-9818ac55571e  Date: 2020-07-04T15:48:19.024Z, Instrument: MS...
# 1194f5ce-1113-4075-adf0-b6c6298005f0  Date: 2020-07-04T15:48:19.024Z, Instrument: MS...
# ...

# %%
index = df.index.values

# %%
index
# Out:
# array(['e7374d4a-c176-464c-b2dc-abc15c55e482',
#        '86f3855e-f825-4e6f-be82-7a814cd1815a',
#        'b890b664-1628-46a4-9fb7-ee96d1e8d9f1',
#        '4f985684-e7b0-4ce1-9fc7-00d5818211ae',
#        '25b2da07-a440-46c8-829c-cfbe7f2b72be',
#        'f846d1a1-40df-4d43-b144-6b42d1aa99d4',
#        '99d48837-c73e-4916-9d87-8c17ee9c3c0e',
#        '59d48a05-0a60-4224-9b93-27787708cffc',
#        '0fa56580-65cd-4d9e-a1b0-9818ac55571e',
#        '1194f5ce-1113-4075-adf0-b6c6298005f0',
#        '3a6aa9d3-9d4b-4efe-accf-8ec4e2587810',
#        '3fe5f15f-b547-45ea-b9c2-eb8dc67c3e97',
#        'b3232a88-e1d2-4ae1-aec7-ffe69fc9cdc9',
#        '7b7e3f08-837e-4e29-8162-e2e0f1bcdc35',
#        '2c77631a-deaf-4b6d-a359-f64649737947',
#        '8d0f956a-b610-4f5d-8adf-fcc3c3e2353b',
#        '0b36b37e-03c7-40eb-afbc-ababbd7176a5',
#        'b2641eb6-47cf-435a-8fa2-c926be3e8048',
#        '396275d8-4cde-425d-bba4-3786db0335c8',
#        '83ac9584-fc87-4771-81ee-7f9b9b425705',
# ...

# %%
project.download_data('0b36b37e-03c7-40eb-afbc-ababbd7176a5')
# Out:
# Downloading: 100%|██████████| 1.23G/1.23G [11:07<00:00, 1.84MB/s]
# MD5 checksumming: 100%|██████████| 1.23G/1.23G [00:01<00:00, 656MB/s]

# %% [markdown]
# # Nile

# %%
from project_manager import ProjectManager

# %%
project = ProjectManager('nile')
# Out:
# project created succesfully

# %%
project.save_catalog()

# %%
df = project.get_dataframe()

# %%
df.shape
# Out:
# (80, 9)

# %%
df = df[df.cloudcoverpercentage < 2]

# %%
df.sort_values(['vegetationpercentage'])
# Out:
#                                                                                 summary  \
# 5c02eb8f-71f2-4737-ae64-1cf1505c0e3b  Date: 2020-05-20T08:16:09.024Z, Instrument: MS...
# 37fc9d69-11eb-4789-afe6-439e3581aa27  Date: 2020-04-15T08:16:01.024Z, Instrument: MS...
# d8d3c0d7-ed4f-42a0-a2f4-d83210cd10ef  Date: 2020-04-05T08:16:01.024Z, Instrument: MS...
# ba592534-05e1-42db-88ef-27c5e73eae2e  Date: 2020-03-31T08:15:59.024Z, Instrument: MS...
# 07da9443-4f62-4bc6-89a0-b5abf3b2e73b  Date: 2020-03-26T08:16:01.024Z, Instrument: MS...
# 892026d6-078d-4e1d-9403-f065e2b324e6  Date: 2020-04-20T08:15:59.024Z, Instrument: MS...
# 0556e4e1-b616-428d-9277-980ad9b09cd1  Date: 2020-04-25T08:16:11.024Z, Instrument: MS...
# 4e5ff9e9-880a-4009-94c0-53667420fe13  Date: 2020-09-12T08:16:11.024Z, Instrument: MS...
# 420506f5-5682-4544-9461-6b6419f94479  Date: 2020-05-05T08:16:11.024Z, Instrument: MS...
# 33cc96da-1a05-477f-8363-4d9a8722c133  Date: 2020-04-10T08:15:59.024Z, Instrument: MS...
# ...

# %%
index = df.sort_values(['vegetationpercentage']).index.values

# %%
project.download_data(index[0])
# Out:
# Downloading: 100%|██████████| 1.04G/1.04G [08:23<00:00, 2.07MB/s]
# MD5 checksumming: 100%|██████████| 1.04G/1.04G [00:01<00:00, 647MB/s]

# %%
project.batch_create_imagery()
# Out:
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:131: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((green+vnir) == 0, 0, (green-vnir)/(green+vnir))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:99: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((swir+nir) == 0, 0, (swir-nir)/(swir+nir))

# %%
project.download_data(df.index.values[0])
# Out:
# Downloading: 100%|██████████| 1.19G/1.19G [10:14<00:00, 1.94MB/s]
# MD5 checksumming: 100%|██████████| 1.19G/1.19G [00:01<00:00, 655MB/s]

# %%
from project_manager import ProjectManager
project= ProjectManager('arsuk')
# Out:
# project already exists

# %%
project.get_footprint()

# %%
project.save_catalog()
# Out:
# Querying products: 100%|██████████| 909/909 [00:12<00:00, 62.63 products/s]

# %%
df = project.get_dataframe()

# %%
df
# Out:
#                                                                                 summary  \
# d59db97a-1694-4182-9cef-fe1dc62331b2  Date: 2020-11-15T14:45:01.024Z, Instrument: MS...
# 169760f3-9d94-4645-af38-dd19af76e544  Date: 2020-11-15T14:45:01.024Z, Instrument: MS...
# e9312fce-d169-4842-9e29-e595c6e0fa7a  Date: 2020-11-13T14:54:59.024Z, Instrument: MS...
# 959938b5-b774-40c4-a81c-edae30d229d7  Date: 2020-11-13T14:54:59.024Z, Instrument: MS...
# 870e12b9-a216-46f9-9bf7-7702085c7321  Date: 2020-11-10T14:44:39.024Z, Instrument: MS...
# ...                                                                                 ...
# 7806a0df-31ea-4c8f-8098-8ecd2e31c414  Date: 2019-10-07T14:40:59.024Z, Instrument: MS...
# a75b9ee9-cf5f-4356-a4f3-034413a94320  Date: 2019-10-05T14:50:51.024Z, Instrument: MS...
# b7a7843b-1fa1-4196-957a-fca97b764d66  Date: 2019-10-05T14:50:51.024Z, Instrument: MS...
# 29c670ce-df12-41f6-aaaf-6f42b6bc0199  Date: 2019-10-02T14:40:31.024Z, Instrument: MS...
# ...

# %%
noclouds = df[df.cloudcoverpercentage < 1]

# %%
noclouds
# Out:
#                                                                                 summary  \
# b836f22b-9616-4d29-8703-b9ed6d98d181  Date: 2020-08-20T14:49:21.024Z, Instrument: MS...
# 79ec38ec-d284-43d2-8103-10fe5f97dfff  Date: 2020-08-20T14:49:21.024Z, Instrument: MS...
# 6c179124-24e5-4055-83ff-ac7ebf27f425  Date: 2020-08-17T14:39:31.024Z, Instrument: MS...
# 8fb3bd31-9faa-492f-b17b-7a57b0e3610e  Date: 2020-08-10T14:49:21.024Z, Instrument: MS...
# 7f054cf9-e793-442e-9ba3-c1376b34485e  Date: 2020-08-10T14:49:21.024Z, Instrument: MS...
# 8828661d-340c-446f-83c7-7d1b5a048f27  Date: 2020-07-18T14:39:31.024Z, Instrument: MS...
#
#                                       vegetationpercentage  \
# b836f22b-9616-4d29-8703-b9ed6d98d181              6.109605
# 79ec38ec-d284-43d2-8103-10fe5f97dfff              9.794159
# 6c179124-24e5-4055-83ff-ac7ebf27f425              7.974884
# 8fb3bd31-9faa-492f-b17b-7a57b0e3610e             10.041522
# ...

# %%
noclouds.shape
# Out:
# (6, 9)

# %%
project.download_data(noclouds.index.values[0])
# Out:
# Downloading: 100%|██████████| 371M/371M [03:37<00:00, 1.71MB/s]
# MD5 checksumming: 100%|██████████| 371M/371M [00:00<00:00, 637MB/s]

# %%
project.batch_create_imagery()
# Out:
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:131: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((green+vnir) == 0, 0, (green-vnir)/(green+vnir))
# /mnt/alex/ssd/Machine learning/satelliteImagery/src/image_creator.py:99: RuntimeWarning: invalid value encountered in true_divide
#   ndbi = np.where((swir+nir) == 0, 0, (swir-nir)/(swir+nir))

# %%
from project_manager import ProjectManager
project = ProjectManager('sanfrancisco')
# Out:
# project created succesfully

# %%
project.save_catalog()
# Out:
# Querying products: 100%|██████████| 167/167 [00:02<00:00, 25.65 products/s]

# %%
df = project.get_dataframe()

# %%
df = df[df.cloudcoverpercentage < 0.5]

# %%
noclouds = df.index.values

# %%
project.download_data(noclouds[0])
# Out:
# Downloading: 100%|██████████| 999M/999M [16:32<00:00, 1.01MB/s]
# MD5 checksumming: 100%|██████████| 999M/999M [00:01<00:00, 648MB/s]

# %%
project.batch_create_imagery()
