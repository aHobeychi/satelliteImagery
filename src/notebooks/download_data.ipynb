# %% [markdown]
# # How To Download The Data

# %%
from project_manager import ProjectManager

# %% [markdown]
# ## 1. Save A Kml File holding the desired coordinates to the kmlFiles Folder in The Project Directory and Then Create A New Project Passing Through The Same Name as The Kml File

# %%
project = ProjectManager('montreal')
# Out:
# project already exists

# %% [markdown]
# ### The footprint of the KmlFile

# %%
project.get_footprint()

# %% [markdown]
# ## 2. Request A Catalog From the Api and Save it to a Csv File

# %%
project.save_catalog()
# Out:
# Querying products: 100%|██████████| 164/164 [00:00<00:00, 71.94 products/s]

# %% [markdown]
# ## 3. Get, Inspect The Catalog and filter out all values that have to much cloud coverage

# %%
catalog = project.get_dataframe()

# %%
catalog.head(5)
# Out:
#                                                                                 summary  \
# 582a687b-53cc-4e13-b83d-d0d60b4b9507  Date: 2020-11-11T15:55:09.024Z, Instrument: MS...
# 1d028000-6495-4afa-907f-6d7b8beeb644  Date: 2020-11-11T15:55:09.024Z, Instrument: MS...
# 65880e4b-226f-4860-9e1d-a49799321201  Date: 2020-11-06T15:54:51.024Z, Instrument: MS...
# 05dcc765-85a9-4a7e-913b-c834a04bc692  Date: 2020-11-06T15:54:51.024Z, Instrument: MS...
# c6ade736-4009-490d-a616-363d2af2761a  Date: 2020-11-01T15:54:19.024Z, Instrument: MS...
#
#                                       vegetationpercentage  \
# 582a687b-53cc-4e13-b83d-d0d60b4b9507              0.000000
# 1d028000-6495-4afa-907f-6d7b8beeb644              0.000000
# 65880e4b-226f-4860-9e1d-a49799321201             17.292108
# 05dcc765-85a9-4a7e-913b-c834a04bc692              0.062243
# c6ade736-4009-490d-a616-363d2af2761a              0.012754
#
#                                       notvegetatedpercentage  waterpercentage  \
# ...

# %%
catalog = catalog[catalog.cloudcoverpercentage < 1]
catalog.head(5)
# Out:
#                                                                                 summary  \
# 86f3855e-f825-4e6f-be82-7a814cd1815a  Date: 2020-10-12T15:51:19.024Z, Instrument: MS...
# b890b664-1628-46a4-9fb7-ee96d1e8d9f1  Date: 2020-10-12T15:51:19.024Z, Instrument: MS...
# 25b2da07-a440-46c8-829c-cfbe7f2b72be  Date: 2020-09-22T15:48:59.024Z, Instrument: MS...
# b3232a88-e1d2-4ae1-aec7-ffe69fc9cdc9  Date: 2020-04-25T15:48:09.024Z, Instrument: MS...
# b220e38e-b84c-4958-8ba7-b27dc6256066  Date: 2019-10-13T15:52:11.024Z, Instrument: MS...
#
#                                       vegetationpercentage  \
# 86f3855e-f825-4e6f-be82-7a814cd1815a             54.116380
# b890b664-1628-46a4-9fb7-ee96d1e8d9f1             51.550978
# 25b2da07-a440-46c8-829c-cfbe7f2b72be             76.418114
# b3232a88-e1d2-4ae1-aec7-ffe69fc9cdc9             17.100659
# b220e38e-b84c-4958-8ba7-b27dc6256066             56.355542
#
#                                       notvegetatedpercentage  waterpercentage  \
# ...

# %% [markdown]
# ## 4. From here decide which Image You would Like to Download and Download using download_data and the Indx

# %%
desired_index = catalog.index.values[0]
project.download_data(desired_index)
# Out:
# Downloading: 100%|██████████| 1.17G/1.17G [06:31<00:00, 3.00MB/s]
# MD5 checksumming: 100%|██████████| 1.17G/1.17G [00:01<00:00, 670MB/s]

# %% [markdown]
# ## 5. Lets Inspect The True Color Image (RGB) of the data we downloaded

# %%
import matplotlib.pyplot as plt
from display import tci_to_array

# %%
image_path = '../projects/montreal/data/2020_10_12/GRANULE/L2A_T18TWR_A018813_20201012T160019/IMG_DATA/R10m/T18TWR_20201012T155119_TCI_10m.jp2'
img = tci_to_array(image_path)

# %%
plt.figure(figsize=(12,12))
plt.imshow(img)
